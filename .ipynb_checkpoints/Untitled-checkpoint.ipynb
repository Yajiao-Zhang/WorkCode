# %%
# import numpy as np
import matplotlib.pyplot as plt

# %%
4.8*3
# Out:
# 14.399999999999999

# %%
a,b,c = 2.5 ,5.6,14.1
abc = a+b+c
sum_d = 50-4.8
for i in [a,b,c]:
    print(i/abc*sum_d)
# Out:
# 5.09009009009009
# 11.4018018018018
# 28.708108108108107

# %%
y= np.array([1,2,3,4123,5,1,532,34])

# %%
x = np.array(range(len(y)))

# %%
x.max()
# Out:
# 7

# %%
plt.plot(x,y)
plt.ylim(y.min(),y.max())
# Out:
# (1.0, 4123.0)
