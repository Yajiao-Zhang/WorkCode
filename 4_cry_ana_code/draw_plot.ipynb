# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
all_12k = [[0,0.1052,2.21],[5,0.1069,3.04],[10,0.1059,2.27],[15,0.1062,2.27],[20,0.1069,2.65],[25,0.107,2.8],\
           [30,0.1069,2.27],[35,0.1071,2.93],[40,0.1078,3.06],[45,0.1061,2.49],[50,0.1078,2.78]]
all_12k = np.array(all_12k)
all_12k = all_12k[:,1:]
all_12k
# Out:
# array([[0.1052, 2.21  ],
#        [0.1069, 3.04  ],
#        [0.1059, 2.27  ],
#        [0.1062, 2.27  ],
#        [0.1069, 2.65  ],
#        [0.107 , 2.8   ],
#        [0.1069, 2.27  ],
#        [0.1071, 2.93  ],
#        [0.1078, 3.06  ],
#        [0.1061, 2.49  ],
#        [0.1078, 2.78  ]])

# %%
all_14k = [0.1016,2.19,0.1062,2.73,0.1066,3.02,0.1061,2.67,0.1074,3.06,0.1076,2.87,0.1087,3.17,0.107,2.52,0.1065,2.62,0.1071,2.97,0.1072,2.73]
all_14k = np.array(all_14k).reshape(-1,2)
# Out:
# array([[0.1016, 2.19  ],
#        [0.1062, 2.73  ],
#        [0.1066, 3.02  ],
#        [0.1061, 2.67  ],
#        [0.1074, 3.06  ],
#        [0.1076, 2.87  ],
#        [0.1087, 3.17  ],
#        [0.107 , 2.52  ],
#        [0.1065, 2.62  ],
#        [0.1071, 2.97  ],
#        [0.1072, 2.73  ]])

# %%
all_16k = [0.1047,2.54,0.1055,2.54,0.1065,2.45,0.1061,2.91,0.1061,2.69,0.1069,3.13,0.1079,3.28,0.1065,2.71,0.108,3.15,0.1061,2.8,0.106,2.45]
all_16k = np.array(all_16k).reshape(-1,2)

# %%
all_18k = [0.1054,2.71,0.1041,2.23,0.107,3.3,0.1053,2.21,0.1042,2.01,0.107,2.69,0.1035,2.1,0.1072,3.61,0.1063,2.41,0.1042,2.08,0.1057,2.3]
all_18k = np.array(all_18k).reshape(-1,2)

# %%
all_20k = [0.1042,2.27,0.1045,2.01,0.104,2.43,0.1059,2.1,0.1045,1.97,0.1047,1.99,0.104,2.03,0.104,1.9,0.1046,2.12,0.1043,2.21,0.1043,2.23]
all_20k = np.array(all_20k).reshape(-1,2)

# %%
all_x = np.linspace(0,50,11)

# %%
import matplotlib.pyplot as plt

# 假设有两个数据集，分别是data1和data2
data1_x = all_x
data1_y = all_12k[:,0]
data2_y = all_12k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue')
ax1.set_xlabel('X (ns)')
ax1.set_ylabel('Q4-mean', color='blue')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red')
plt.title('Q4 varies - 1200K')
plt.show()

# %%
# 设置字体样式
plt.rcParams['font.family'] = 'Times New Roman'  # 设置为黑体
plt.rcParams['font.weight'] = 'bold'    # 设置为加粗
plt.figure(dpi=120)
plt.plot(all_x, all_12k[:,0],marker='o',label = '1200K')
plt.plot(all_x, all_14k[:,0],marker='o',label = '1400K')
plt.plot(all_x, all_16k[:,0],marker='o',label = '1600K')
plt.plot(all_x, all_18k[:,0],marker='o',label = '1800K')
plt.plot(all_x, all_20k[:,0],marker='o',label = '2000K')
plt.title('Mean value of Q4', fontsize=20, fontweight='bold')
plt.xlabel('time (ns)', fontsize=17, fontweight='bold')
plt.ylabel('Q4 value', fontsize=17, fontweight='bold')
# 设置刻度标签字体样式
plt.xticks(fontsize=15)  # 设置X轴刻度字体大小
plt.yticks(fontsize=15)  # 设置Y轴刻度字体大小
plt.legend()

# %%
# 设置字体样式
plt.rcParams['font.family'] = 'Times New Roman'  # 设置为黑体
plt.rcParams['font.weight'] = 'bold'    # 设置为加粗
plt.figure(dpi=120)
plt.title('Percentage of Q4 > 0.16', fontsize=21, fontweight='bold')
plt.plot(all_x, all_12k[:,1],marker='o',label = '1200K')
plt.plot(all_x, all_14k[:,1],marker='o',label = '1400K')
plt.plot(all_x, all_16k[:,1],marker='o',label = '1600K')
plt.plot(all_x, all_18k[:,1],marker='o',label = '1800K')
plt.plot(all_x, all_20k[:,1],marker='o',label = '2000K')
plt.xlabel('time (ns)', fontsize=17, fontweight='bold')
plt.ylabel('Percentage of Q4 > 0.16 (%)', fontsize=17, fontweight='bold')
# 设置刻度标签字体样式
plt.xticks(fontsize=15)  # 设置X轴刻度字体大小
plt.yticks(fontsize=15)  # 设置Y轴刻度字体大小
plt.legend()

# %%
import matplotlib.pyplot as plt

# 假设有两个数据集，分别是data1和data2
data1_x = all_x
data1_y = all_14k[:,0]
data2_y = all_14k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue')
ax1.set_xlabel('X (ns)')
ax1.set_ylabel('Q4-mean', color='blue')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red')
plt.title('Q4 varies - 1400K')
plt.show()

# %%
import matplotlib.pyplot as plt

# 假设有两个数据集，分别是data1和data2
data1_x = all_x
data1_y = all_16k[:,0]
data2_y = all_16k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue')
ax1.set_xlabel('X (ns)')
ax1.set_ylabel('Q4-mean', color='blue')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red')
plt.title('Q4 varies - 1600K')
plt.show()

# %%
# 设置字体样式
plt.rcParams['font.family'] = 'Times New Roman'  # 设置为黑体
plt.rcParams['font.weight'] = 'bold'    # 设置为加粗
plt.figure(dpi=150)

# 假设有两个数据集，分别是data1和data2
data1_x = all_x
data1_y = all_18k[:,0]
data2_y = all_18k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, marker='o',color='blue')

ax1.set_ylabel('Q4-mean',color='blue', fontsize=18, fontweight='bold')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y,marker='o', color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red', fontsize=17, fontweight='bold')
plt.title('Q4 varies - 1800K', fontsize=18, fontweight='bold')

plt.show()

# %%
# 设置字体样式
plt.rcParams['font.family'] = 'Times New Roman'  # 设置为黑体
plt.rcParams['font.weight'] = 'bold'    # 设置为加粗
plt.figure(dpi=150)

# 假设有两个数据集，分别是data1和data2
data1_x = all_x
data1_y = all_20k[:,0]
data2_y = all_20k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, marker='o',color='blue')

ax1.set_ylabel('Q4-mean',color='blue', fontsize=18, fontweight='bold')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y,marker='o', color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red', fontsize=17, fontweight='bold')
plt.title('Q4 varies - 2000K', fontsize=18, fontweight='bold')

plt.show()

# %%
import matplotlib.pyplot as plt

# 假设有两个数据集，分别是data1和data2
data1_x = all_x
data1_y = all_20k[:,0]
data2_y = all_20k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue')
ax1.set_xlabel('X (ns)')
ax1.set_ylabel('Q4-mean', color='blue')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red')
plt.title('Q4 varies - 2000K')
plt.show()

# %%
import matplotlib.pyplot as plt

# 假设有两个数据集，分别是data1和data2
data1_x = all_12k[:,0]
data1_y = all_12k[:,1]

data2_y = all_12k[:,2]

fig, ax1 = plt.subplots()

# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue')
ax1.set_xlabel('X')
ax1.set_ylabel('Q4-mean', color='blue')

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red')
plt.title('Q4 varies with tempture')
plt.show()

# %%
# 首先是看均值和峰值有没有关系
mean_15k =[1042,1068,1078,1064,1084,1058,1061,1077,1066,1072,1095] 
max_15k = [61,97,101,79,109,82,74,110,73,82,99]
mean_15k = np.array(mean_15k)
max_15k = np.array(max_15k)

# %%
plt.plot(range(len(mean_15k)),mean_15k-1000,label = '15-mean')
plt.plot( range(len(max_15k)),max_15k, label = '15-max')
plt.legend()

# %%
mean_16k = [1047,1055,1065,1061,1061,1069,1079,1065,1080,1061,1060]
max_16k = [78,79,76,85,79,84,102,79,90,76,80]
mean_16k = np.array(mean_16k)
max_16k = np.array(max_16k)
plt.plot(range(len(mean_16k)),mean_16k-1000,label = '16-mean')
plt.plot( range(len(max_16k)),max_16k, label = '16-max')
plt.legend()

# %%
mean_17k = np.array([1047,1053,1052,1058,1059,1038])
max_17k = np.array([70,71,63,54,71,50])
plt.plot(range(len(mean_17k)),mean_17k-950,label = '17-mean')
plt.plot( range(len(max_17k)),max_17k, label = '17-max')
plt.legend()

# %%
plt.plot(range(len(mean_15k)),mean_15k,label = 'mean-15')
plt.plot(range(len(mean_16k)),mean_16k,label = 'mean-16')
plt.plot(range(len(mean_17k)),mean_17k,label = 'mean-17')
#plt.plot(range(len(mean_18k)),mean_18k,label = 'mean-17')
plt.legend()

# %%
plt.plot(range(len(max_15k)),max_15k,label = 'max-15')
plt.plot(range(len(max_16k)),max_16k,label = 'max-16')
plt.plot(range(len(max_17k)),max_17k,label = 'max-17')
#plt.plot(range(len(max_18k)),max_18k,label = 'max-18')
plt.legend()

# %%
cooling = np.array([[0.0956,45,5000],[0.1018,64,4500],[0.1039,73,4000],[0.1054,97,3500]\
           ,[0.1071,100,3000],[0.1072,124,2700],[0.1092,115,2500],[0.1105,138,2300],[0.1121,162,2000],[0.113,167,1900],[0.1119,147,1800]\
         ,[0.1123,181,1700],[0.1127,174,1600]\
           ,[0.1135,176,1500],[0.1139,182,1400],[0.1134,177,1300],[0.1132,181,1200],[0.1135,179,1100],[0.1136,207,1000]\
            ,[0.1132,190,900],[0.1131,161,800],[0.1132,183,700],[0.1136,186,400]])

# %%
plt.plot(cooling[:,2], cooling[:,1])
plt.xlabel('Tempture (K)')
plt.ylabel('Q4 > 0.16')
plt.title('Q4 > 0.16 varies during cooling')
# Out:
# Text(0.5, 1.0, 'Q4 > 0.16 varies during cooling')

# %%
plt.plot(cooling[:,2], cooling[:,0])
plt.xlabel('Q4-mean')
plt.ylabel('Q4 > 0.16')
plt.title('q4-mean ')
# Out:
# Text(0.5, 1.0, 'q4-mean ')

# %%
plt.plot(cooling[:,0], cooling[:,1])
plt.xlabel('Q4-mean')
plt.ylabel('Q4 > 0.16')
plt.title('Q4-mean vs Q4-max')
# Out:
# Text(0.5, 1.0, 'Q4-mean vs Q4-max')

# %%
import matplotlib.pyplot as plt

# 假设有两个数据集，分别是data1和data2
data1_x = cooling[:,2]
data1_y = cooling[:,0]

data2_y = cooling[:,1]

fig, ax1 = plt.subplots()

# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue')
ax1.set_xlabel('X')
ax1.set_ylabel('Q4-mean', color='blue')

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red')
ax2.set_ylabel('Q4 > 0.16', color='red')
plt.title('Q4 varies with tempture')
plt.show()

# %% [markdown]
# # 冷却过程的cooling 重新计算一次

# %%
# 从5000K冷却到300K，那就采47个点吧
cooling_out= [0.0985,1.35,5000,0.0977,1.11,4900,0.0986,1.13,4800,0.0986,1.67,4700,0.0986,1.42,4600,0.0991,1.32,4500,\
              0.099,1.26,4400,0.0992,1.43,4300,0.0995,1.37,4200,0.0999,1.22,4100,0.1005,1.58,4000,0.0995,1.17,3900,\
             0.0998,1.34,3800,0.1013,1.92,3700,0.1016,1.74,3600,0.1012,1.42,3500,0.1029,1.79,3400,0.1022,2.08,3300,\
             0.1029,1.96,3200,0.1013,1.88,3100,0.104,2.4,3000,0.1032,2.17,2900,0.1035,1.9,2800,0.1048,2.38,2700,\
             0.1041,2.16,2600,0.1069,2.96,2500,0.1069,3.19,2400,0.1073,3.43,2300,0.1069,3.01,2200,0.1079,3.11,2100,\
             0.1084,3.6,2000,0.1064,2.64,1900,0.1087,3.06,1800,0.1086,2.88,1700,0.1084,3.41,1600,0.1077,3.22,1500,\
             0.1082,3.09,1400,0.1084,3.51,1300,0.1082,3.17,1200,0.1084,3.11,1100,0.1089,3.54,1000,0.1091,3.69,900,\
             0.1097,3.49,800,0.1101,3.6,700,0.11,3.8,600,0.1109,4.31,500,0.1103,4.23,400,0.111,4.07,300]

# %%
cooling_out = np.array(cooling_out).reshape(-1,3)

# %%
import matplotlib.pyplot as plt

# 设置字体样式
plt.rcParams['font.family'] = 'Times New Roman'  # 设置为黑体
plt.rcParams['font.weight'] = 'bold'    # 设置为加粗

# 假设有两个数据集，分别是data1和data2
data1_x = cooling_out[:,2]
data1_y = cooling_out[:,0]
data2_y = cooling_out[:,1]

fig, ax1 = plt.subplots()
plt.figure(dpi=120)

# 绘制第一个数据集
ax1.plot(data1_x, data1_y, color='blue',marker='o',label = 'Mean')
ax1.set_xlabel('X', fontsize=17, fontweight='bold')
ax1.set_ylabel('Q4-mean', color='blue', fontsize=17, fontweight='bold')

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y, color='red',marker='o',label = 'Hieher')
ax2.set_ylabel('Q4 > 0.16', color='red', fontsize=17, fontweight='bold')
# Out:
# Text(0, 0.5, 'Q4 > 0.16')

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# 设置字体样式
font = FontProperties(family='serif', style='normal', weight='bold', size=16)

# 构造数据
x = cooling_out[:,2]
y1 = cooling_out[:,0]
y2 = cooling_out[:,1]


# 创建图形并设置尺寸和分辨率
plt.figure(figsize=(8,6),dpi=120)

# 绘制第一个 y 值对应的线图
color = 'tab:blue'
plt.xlabel('Temperture (K)', fontproperties=font)
plt.ylabel('Q4-mean', color=color, fontproperties=font)
plt.plot(x, y1, color=color, marker='o', linestyle='-', label='Y1')
plt.tick_params(axis='y', labelcolor=color)
# plt.legend()
# 创建第二个 y 坐标轴
plt.twinx()

# 绘制第二个 y 值对应的线图
color = 'tab:red'
plt.ylabel('Q4 > 0.16 (%)', color=color, fontproperties=font)
plt.plot(x, y2, color=color, marker='s', linestyle='--', label='Y2')
plt.tick_params(axis='y', labelcolor=color)

plt.xticks(np.arange(300, 5000, 500))

# 添加标题和图例
plt.title('Q4-value varies at cooling proccess(5000K-300K)', fontproperties=font)
# plt.legend()

plt.show()

# %% [markdown]
# # 这里是分析的是LAS晶体生长过程中的变化趋势

# %%
# 250frame - 80 ns 还是取25个点看看
las_19k = [0.1237,20.59,0.1327,29.89,0.1416,41.19,0.1492,49.43,0.1526,54.14,0.1625,\
           64.88,0.1762,79.71,0.1815,87.65,0.1867,93.06,0.1893,96.03,0.1879,96.03]
las_19k = np.array(las_19k).reshape(-1,2)
las_x = np.linspace(0,80,len(las_19k))

# %%
# Out:
# array([ 0.,  8., 16., 24., 32., 40., 48., 56., 64., 72., 80.])

# %%
# 设置字体样式
plt.rcParams['font.family'] = 'Times New Roman'  # 设置为黑体
plt.rcParams['font.weight'] = 'bold'    # 设置为加粗
plt.figure(dpi=150)

# 假设有两个数据集，分别是data1和data2
data1_x = las_x
data1_y = las_19k[:,0]
data2_y = las_19k[:,1]

fig, ax1 = plt.subplots()
# 绘制第一个数据集
ax1.plot(data1_x, data1_y, marker='o',color='blue')

ax1.set_ylabel('Q4-mean',color='blue', fontsize=18, fontweight='bold')
# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(data1_x, data2_y,marker='o', color='red')
ax2.set_ylabel('Q4 > 0.16 (%)', color='red', fontsize=17, fontweight='bold')
plt.title('Q4 varies in LAS seed-method at 1900K for 80ns', fontsize=18, fontweight='bold')

plt.show()
