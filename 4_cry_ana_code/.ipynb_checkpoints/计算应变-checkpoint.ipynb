# %%
import pandas as pd

file_path = r'C:\Users\zhang\Desktop\md\2024corning\june\tension\tension-process_out.xyz'

# 打开一个文本文件，准备写入 strain 数据
output_file_path = r'C:\Users\zhang\Desktop\md\2024corning\june\tension\strain_data.txt'

# %%
#
start_frame = 0
end_frame = 101
step_frame = 1
#

# %%
# 存储原子坐标的列表
atom_data = []
# 
with open(file_path, 'r') as f:
    n_lines = 0
    n_atoms = 0
    n_frames = 0
    for line in f:
        tmp_line = line.split()
        if tmp_line:
            if n_lines == 0:
                n_atoms = int(tmp_line[0])
                n_lines += 1
            if tmp_line[0] == 'Atoms':
                n_frames += 1
print(n_lines, n_frames, n_atoms)
# Out:
# 1 101 5030

# %%
# 读一帧  分析一帧
file = open(file_path, 'r')
x0 = 105.08
output_file = open(output_file_path, 'w')
for frame in range(start_frame,end_frame,step_frame):
    print('analysis frame: ',frame)
    num_atoms = int(file.readline())
    # 跳过Atoms
    file.readline()
    
    x_list = []
    y_list = []
    z_list = []
    x_min = 1
    x_max = 0
    y_min = 1
    y_max = 0 
    z_min = 100
    z_max = 0
    for atom in range(num_atoms):
        row_atom = file.readline().split()
        x,y,z = float(row_atom[1]),float(row_atom[2]),float(row_atom[3])
        row_atom = [row_atom[0],x,y,z]
        #print(row_atom)
        
        if x > x_max:
            x_max = x
        if y > y_max:
            y_max = y
        if z > z_max:
            z_max = z
        if x < x_min:
            x_min = x
        if y < y_min:
            y_min = y
        if z < z_min:
            z_min = z
        delta_x = x_max - x_min
    print('x_max: ', x_max)
    print('y_max: ', y_max)
    print('z_max: ', z_max)
    print('x_min: ', x_min)
    print('y_min: ', y_min)
    print('z_min: ', z_min)
    print('x轴长度：', delta_x)
    strain = (delta_x - x0)/x0
    print('应变为',strain )
    #将所求的应变strain数据导出
    #output_file.write(f'{frame} {strain}\n')
    output_file.write(f'{strain}\n')
output_file.close()
file.close()
# Out:
# analysis frame:  0
# x_max:  175.183434
# y_max:  52.862177
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.039823
# z_min:  0.00693
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  1
# x_max:  175.183434
# y_max:  52.851677
# z_max:  10.99422
# x_min:  0.040134
# y_min:  0.004415
# z_min:  0.00014
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  2
# x_max:  175.183434
# y_max:  52.862977
# z_max:  10.99782
# x_min:  0.040134
# y_min:  0.001668
# z_min:  0.00094
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  3
# x_max:  175.183434
# y_max:  52.870277
# z_max:  10.99662
# x_min:  0.040134
# y_min:  0.028034
# z_min:  0.00327
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  4
# x_max:  175.183434
# y_max:  52.870577
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.00708
# z_min:  0.00271
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  5
# x_max:  175.183434
# y_max:  52.863377
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.001283
# z_min:  0.0004
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  6
# x_max:  175.183434
# y_max:  52.866977
# z_max:  10.99692
# x_min:  0.040134
# y_min:  0.051188
# z_min:  0.00155
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  7
# x_max:  175.183434
# y_max:  52.858677
# z_max:  10.99502
# x_min:  0.040134
# y_min:  0.038104
# z_min:  7e-05
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  8
# x_max:  175.183434
# y_max:  52.867777
# z_max:  10.99592
# x_min:  0.040134
# y_min:  0.010366
# z_min:  0.00168
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  9
# x_max:  175.183434
# y_max:  52.866177
# z_max:  10.99782
# x_min:  0.040134
# y_min:  0.008939
# z_min:  0.01425
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  79
# x_max:  175.183434
# y_max:  52.852877
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.01243
# z_min:  0.00184
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  80
# x_max:  175.183434
# y_max:  52.851477
# z_max:  10.99462
# x_min:  0.040134
# y_min:  0.008878
# z_min:  0.00233
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  81
# x_max:  175.183434
# y_max:  52.846877
# z_max:  10.99542
# x_min:  0.040134
# y_min:  0.004881
# z_min:  0.0017
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  82
# x_max:  175.183434
# y_max:  52.857277
# z_max:  10.99422
# x_min:  0.040134
# y_min:  0.01918
# z_min:  0.00054
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  83
# x_max:  175.183434
# y_max:  52.867977
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.002783
# z_min:  0.00068
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  84
# x_max:  175.183434
# y_max:  52.859977
# z_max:  10.99752
# x_min:  0.040134
# y_min:  0.014877
# z_min:  0.00298
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  85
# x_max:  175.183434
# y_max:  52.867177
# z_max:  10.99762
# x_min:  0.040134
# y_min:  0.009233
# z_min:  0.00184
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  86
# x_max:  175.183434
# y_max:  52.865677
# z_max:  10.99392
# x_min:  0.000834
# y_min:  0.004627
# z_min:  0.00055
# x轴长度： 175.1826
# 应变为 0.6671355157974878
# analysis frame:  87
# x_max:  175.183434
# y_max:  52.857677
# z_max:  10.99562
# x_min:  0.040134
# y_min:  0.000799
# z_min:  0.00168
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  88
# x_max:  175.183434
# y_max:  52.860477
# z_max:  10.99432
# x_min:  0.040134
# y_min:  0.012888
# z_min:  0.01232
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  89
# x_max:  175.183434
# y_max:  52.848877
# z_max:  10.99712
# x_min:  0.040134
# y_min:  0.013636
# z_min:  0.0032
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  90
# x_max:  175.183434
# y_max:  52.853277
# z_max:  10.99732
# x_min:  0.040134
# y_min:  0.011662
# z_min:  0.00029
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  91
# x_max:  175.183434
# y_max:  52.861577
# z_max:  10.99772
# x_min:  0.040134
# y_min:  0.005856
# z_min:  8e-05
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  92
# x_max:  175.183434
# y_max:  52.858677
# z_max:  10.99472
# x_min:  0.040134
# y_min:  0.000777
# z_min:  0.00024
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  93
# x_max:  175.183434
# y_max:  52.853077
# z_max:  10.99772
# x_min:  0.040134
# y_min:  0.001032
# z_min:  0.00201
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  94
# x_max:  175.183434
# y_max:  52.860177
# z_max:  10.99722
# x_min:  0.040134
# y_min:  0.004502
# z_min:  0.00088
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  95
# x_max:  175.183434
# y_max:  52.861077
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.016645
# z_min:  0.0048
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  96
# x_max:  175.183434
# y_max:  52.848877
# z_max:  10.99612
# x_min:  0.040134
# y_min:  0.007895
# z_min:  0.00126
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  97
# x_max:  175.183434
# y_max:  52.838077
# z_max:  10.99352
# x_min:  0.040134
# y_min:  0.047539
# z_min:  0.00018
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  98
# x_max:  175.183434
# y_max:  52.862177
# z_max:  10.99432
# x_min:  0.040134
# y_min:  0.026694
# z_min:  0.00293
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  99
# x_max:  175.183434
# y_max:  52.859777
# z_max:  10.99752
# x_min:  0.040134
# y_min:  0.001128
# z_min:  0.00027
# x轴长度： 175.1433
# 应变为 0.6667615150361631
# analysis frame:  100
# x_max:  175.183434
# y_max:  52.871277
# z_max:  10.99682
# x_min:  0.040134
# y_min:  0.010176
# z_min:  0.00309
# x轴长度： 175.1433
# 应变为 0.6667615150361631

# %%
file.close()
