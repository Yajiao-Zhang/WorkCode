# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\zhang\Desktop\data.txt"

# %%
with open(path) as f:
    str_data = f.read()
data = str_data.split()

# %%
np_data  = np.array(data)

# %%
np_data
# Out:
# array(['Step', 'Dt', 'Temp', ..., '-87660.503', '76058.943', '4.3964076'],
#       dtype='<U10')

# %%
data1 = np_data[10:]

# %%
data1
# Out:
# array(['0', '0.001', '2228.4313', ..., '-87660.503', '76058.943',
#        '4.3964076'], dtype='<U10')

# %%
data2 = data1.reshape(-1,10)

# %%
data2[0]
# Out:
# array(['0', '0.001', '2228.4313', '125239.89', '-95393.589', '1958.4339',
#        '-93435.155', '-87489.734', '76058.943', '4.3964076'], dtype='<U10')

# %%
# step enthalpy
x,y = [],[]
for i in data2[:-5:100]:
    x.append(float(i[0]))
    y.append(float(i[7]))
plt.scatter(y,x)

# %%
x,y = [],[]
for i in data2[:-5:100]:
    x.append(float(i[2]))
    y.append(float(i[7]))
plt.scatter(y,x)

# %%
x,y = [],[]
for i in data2[:-5:100]:
    x.append(float(i[0]))
    y.append(float(i[4]))
plt.scatter(y,x)

# %%
x,y = [],[]
for i in data2[:-5:100]:
    x.append(float(i[4]))
    y.append(float(i[7]))
plt.scatter(y,x)
